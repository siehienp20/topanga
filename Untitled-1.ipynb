# %%
# !pip install uproot
import uproot as up
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#https://uproot.readthedocs.io/en/latest/basic.html#reading-a-tbranch-as-an-array#

ts = up.open("https://drive.google.com/uc?id=1RP28TFbmUBC1EFV90K0ENL8rung2qUDC:ts")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-991c3036d806> in <module>()
# ----> 1 ts = up.open("https://drive.google.com/uc?id=1RP28TFbmUBC1EFV90K0ENL8rung2qUDC:ts")
#
# /usr/local/lib/python3.7/dist-packages/uproot/reading.py in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     146         decompression_executor=decompression_executor,
#     147         interpretation_executor=interpretation_executor,
# --> 148         **options,  # NOTE: a comma after **options breaks Python 2
#     149     )
#     150
#
# /usr/local/lib/python3.7/dist-packages/uproot/reading.py in __init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     614             self._fUUID,
#     615         ) = uproot.source.cursor.Cursor(0).fields(
# ...

# %%
ts_samples = ts.arrays(['s'], library='pd')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-8b947b3c603a> in <module>()
# ----> 1 ts_samples = ts.arrays(['s'], library='pd')
#
# /usr/local/lib/python3.7/dist-packages/uproot/behaviors/TBranch.py in arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, how)
#    1265             library,
#    1266             arrays,
# -> 1267             False,
#    1268         )
#    1269
#
# /usr/local/lib/python3.7/dist-packages/uproot/behaviors/TBranch.py in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets)
#    3493
#    3494         elif isinstance(obj, tuple) and len(obj) == 3:
# ...

# %%
ts_samples
